# %%
import pandas as pd
from static.src.inquinanti import Inquinante
from static.src.map_data import *
from datetime import datetime

# %%
path = 'static/data/pregressi/data_2018.csv'

# %%
df = pd.read_csv(path, sep='\t')
df.head()
# Out:
#    anno  Preneste  Francia  Villa Ada  Castel di Guido  Cavaliere  Fermi  \
# 0  2018       NaN     80.0       68.0             72.0       60.0    NaN
# 1  2018       NaN     36.0       36.0             32.0       36.0    NaN
# 2  2018       NaN     68.0       64.0             64.0       60.0    NaN
# 3  2018       3.0     25.0        3.5              4.0       15.5   18.5
# 4  2018       NaN     36.0       40.0             36.0       32.0    NaN
#
#    Bufalotta  Cipro  Magna Grecia  Tiburtina  Arenula  Malagrotta  Cinecitta  \
# 0        NaN   68.0           NaN        NaN     60.0        64.0       76.0
# 1        NaN   20.0           NaN        NaN     28.0        32.0       32.0
# 2        NaN   52.0           NaN        NaN      NaN        52.0       64.0
# 3        6.0   11.0           9.5       29.5      2.5         2.0       11.0
# 4        NaN   24.0           NaN        NaN     24.0        32.0       44.0
#
#               data_ora inquinante  ora data_ora_time  limite
# ...

# %%
df_o3.head()
# Out:
#                       2018
# Preneste         29.891583
# Francia                NaN
# Villa Ada        24.553662
# Castel di Guido  37.744731
# Cavaliere        26.251247

# %%
df_o3 = Inquinante('O3', 180, 'hourly').pollutant_dataframe(df)#.average(df, '2018')

# %%
df_media = df_o3.groupby('data_ora_time').max().ix[-1]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df_media.drop(['anno','ora','limite', 'inquinante','data_ora'], inplace=True)

# %%
df_media
# Out:
# Preneste           2.22222
# Francia                NaN
# Villa Ada          3.88889
# Castel di Guido    31.1111
# Cavaliere          19.4444
# Fermi                  NaN
# Bufalotta          3.88889
# Cipro              5.55556
# Magna Grecia           NaN
# Tiburtina              NaN
# Arenula            1.11111
# Malagrotta         17.2222
# Cinecitta          4.44444
# Name: 2018-09-12, dtype: object

# %%
df_media = pd.DataFrame(df_media)
df_media.columns = ['2018']

# %%
df_media
# Out:
#                     2018
# Preneste         2.22222
# Francia              NaN
# Villa Ada        3.88889
# Castel di Guido  31.1111
# Cavaliere        19.4444
# Fermi                NaN
# Bufalotta        3.88889
# Cipro            5.55556
# Magna Grecia         NaN
# Tiburtina            NaN
# Arenula          1.11111
# Malagrotta       17.2222
# Cinecitta        4.44444
